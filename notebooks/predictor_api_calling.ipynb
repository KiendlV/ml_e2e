# %%
import requests

url = "http://localhost/predict"

data = {
    "features": [
        12.5,
        80.0,
        1013.2
    ]
}

response = requests.post(url, json=data)

print(response.json())
# Out:
# {'prediction': 0}
